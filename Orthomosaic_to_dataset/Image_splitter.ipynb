# %% [markdown]
# # Image Splitter for Metashape
# This script aims to split the images stitched and processed with metashape into data that can be fed into a CNN or other machine learning AI.

# %%
# Import OpenCV libraries
import cv2
import matplotlib.pyplot as plt

import numpy as np
import tifffile

# %%
# Import image
img = tifffile.imread('./input/GeoTiff_cropped_2020_06_11.tif')

# Check to make sure we don't import garbage
if img.dtype == np.uint8:
    depth = 8
elif img.dtype == np.uint16:
    depth = 16
else:
    print("Warning: unsupported data type {}. Assuming 16-bit.", img.dtype)
    depth = 16
    
# Find the dimensions and channels of the image
img_height, img_width, img_channels = img.shape
print("Image height (Pixels):\t", img_height)
print("Image width (Pixels):\t", img_width)
print("Image channels:\t\t", img_channels)
print("----------------------------------")

# Calculate corrected image size, so it can be split into 255x255 blocks
img_height_cropped = (int(img_height/256)*256)-1
img_width_cropped = (int(img_width/256)*256)-1

print("Image height cropped:\t", img_height_cropped)
print("Image width cropped:\t", img_width_cropped)
print("----------------------------------")

# Crop the image
img_crop  = img[0:img_height_cropped, 0:img_width_cropped]
img_height_corrected, img_width_corrected, img_channels = img_crop.shape

print("New image height:\t", img_height_corrected)
print("New image width:\t", img_width_corrected)
print("Image channels:\t\t", img_channels)
print("----------------------------------")

img_crop_norm_tmp = np.zeros((img_height_corrected, img_width_corrected))
img_crop = cv2.normalize(img_crop, img_crop_norm_tmp, 0, 255, cv2.NORM_MINMAX)

# Split the image into its cahnnels
img_crop_ch1, img_crop_ch2, img_crop_ch3, img_crop_ch4, img_crop_ch5, img_crop_ch6 = cv2.split(img_crop)

print("Image has been split into 6 seperate images")
# Out:
# Image height (Pixels):	 18392
# Image width (Pixels):	 7368
# Image channels:		 6
# ----------------------------------
# Image height cropped:	 18175
# Image width cropped:	 7167
# ----------------------------------
# New image height:	 18175
# New image width:	 7167
# Image channels:		 6
# ----------------------------------
# Image has been split into 6 seperate images

# %%
# Normalize all chennales individually
# Normalizing channel 1
img_crop_norm_tmp = np.zeros((img_height_corrected, img_width_corrected))
img_crop_ch1 = cv2.normalize(img_crop_ch1, img_crop_norm_tmp, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)

# Normalizing channel 2
img_crop_norm_tmp = np.zeros((img_height_corrected, img_width_corrected))
img_crop_ch2 = cv2.normalize(img_crop_ch2, img_crop_norm_tmp, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)

# Normalizing channel 3
img_crop_norm_tmp = np.zeros((img_height_corrected, img_width_corrected))
img_crop_ch3 = cv2.normalize(img_crop_ch3, img_crop_norm_tmp, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)

# Normalizing channel 4
img_crop_norm_tmp = np.zeros((img_height_corrected, img_width_corrected))
img_crop_ch4 = cv2.normalize(img_crop_ch4, img_crop_norm_tmp, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)

# Normalizing channel 5
img_crop_norm_tmp = np.zeros((img_height_corrected, img_width_corrected))
img_crop_ch5 = cv2.normalize(img_crop_ch5, img_crop_norm_tmp, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)

# Normalizing channel 6
img_crop_norm_tmp = np.zeros((img_height_corrected, img_width_corrected))
img_crop_ch6 = cv2.normalize(img_crop_ch6, img_crop_norm_tmp, 0, 255, cv2.NORM_MINMAX, cv2.CV_8UC1)

# %%
# Import mask
img_mask = cv2.imread('./input/Mask.jpg')

# Check to make sure we don't import garbage
if img_mask.dtype == np.uint8:
    depth = 8
elif img_mask.dtype == np.uint16:
    depth = 16
else:
    print("Warning: unsupported data type {}. Assuming 16-bit.", img_rgb.dtype)
    depth = 16
    
# Find the dimensions and channels of the image
img_mask_height, img_mask_width, img_mask_channels = img_mask.shape
print("Image height (Pixels):\t", img_mask_height)
print("Image width (Pixels):\t", img_mask_width)
print("Image channels:\t\t", img_mask_channels)
print("----------------------------------")

# Calculate corrected image size, so it can be split into 255x255 blocks
img_mask_height_cropped = (int(img_mask_height/256)*256)-1
img_mask_width_cropped = (int(img_mask_width/256)*256)-1

print("Image height cropped:\t", img_mask_height_cropped)
print("Image width cropped:\t", img_mask_width_cropped)
print("----------------------------------")

# Crop the image
img_mask_crop  = img_mask[0:img_mask_height_cropped, 0:img_mask_width_cropped]
img_mask_height_corrected, img_mask_width_corrected, img_mask_channels = img_mask_crop.shape

print("New image height:\t", img_mask_height_corrected)
print("New image width:\t", img_mask_width_corrected)
print("Image channels:\t\t", img_mask_channels)
print("----------------------------------")
# Out:
# Image height (Pixels):	 18392
# Image width (Pixels):	 7368
# Image channels:		 3
# ----------------------------------
# Image height cropped:	 18175
# Image width cropped:	 7167
# ----------------------------------
# New image height:	 18175
# New image width:	 7167
# Image channels:		 3
# ----------------------------------

# %%
# Import RGB reference
img_rgb = cv2.imread('./input/RGB.jpg')


# Check to make sure we don't import garbage
if img_rgb.dtype == np.uint8:
    depth = 8
elif img_rgb.dtype == np.uint16:
    depth = 16
else:
    print("Warning: unsupported data type {}. Assuming 16-bit.", img_rgb.dtype)
    depth = 16
    
# Find the dimensions and channels of the image
img_rgb_height, img_rgb_width, img_rgb_channels = img_rgb.shape
print("Image height (Pixels):\t", img_rgb_height)
print("Image width (Pixels):\t", img_rgb_width)
print("Image channels:\t\t", img_rgb_channels)
print("----------------------------------")

# Calculate corrected image size, so it can be split into 255x255 blocks
img_rgb_height_cropped = (int(img_rgb_height/256)*256)-1
img_rgb_width_cropped = (int(img_rgb_width/256)*256)-1

print("Image height cropped:\t", img_rgb_height_cropped)
print("Image width cropped:\t", img_rgb_width_cropped)
print("----------------------------------")

# Crop the image
img_rgb_crop  = img_rgb[0:img_rgb_height_cropped, 0:img_rgb_width_cropped]
img_rgb_height_corrected, img_rgb_width_corrected, img_rgb_channels = img_rgb_crop.shape


print("New image height:\t", img_rgb_height_corrected)
print("New image width:\t", img_rgb_width_corrected)
print("Image channels:\t\t", img_rgb_channels)
print("----------------------------------")
# Out:
# Image height (Pixels):	 18392
# Image width (Pixels):	 7368
# Image channels:		 3
# ----------------------------------
# Image height cropped:	 18175
# Image width cropped:	 7167
# ----------------------------------
# New image height:	 18175
# New image width:	 7167
# Image channels:		 3
# ----------------------------------

# %%
import os

# Define chunk size and make sure directory paths exist
counter = 0
chunk_size = 128 # In pixels
Path = 'output/'
res = os.system("mkdir -p " + Path + "Field_1")
print(res)
res = os.system("mkdir -p " + Path + "Field_2")
print(res)
res = os.system("mkdir -p " + Path + "Field_3")
print(res)
res = os.system("mkdir -p " + Path + "Field_4")
print(res)
res = os.system("mkdir -p " + Path + "Mask_reference")
print(res)
res = os.system("mkdir -p " + Path + "RGB_reference")
print(res)

# Equalize histograms of all channels and save originals and modified channels
cv2.imwrite(Path + '/image_ch1.jpg', img_crop_ch1)
img_crop_ch1_eq = cv2.equalizeHist(img_crop_ch1)
cv2.imwrite(Path + '/image_eq_ch1.jpg', img_crop_ch1_eq)

cv2.imwrite(Path + '/image_ch2.jpg', img_crop_ch2)
img_crop_ch2_eq = cv2.equalizeHist(img_crop_ch2)
cv2.imwrite(Path + '/image_eq_ch2.jpg', img_crop_ch2_eq)

cv2.imwrite(Path + '/image_ch3.jpg', img_crop_ch3)
img_crop_ch3_eq = cv2.equalizeHist(img_crop_ch3)
cv2.imwrite(Path + '/image_eq_ch3.jpg', img_crop_ch3_eq)

cv2.imwrite(Path + '/image_ch4.jpg', img_crop_ch4)
img_crop_ch4_eq = cv2.equalizeHist(img_crop_ch4)
cv2.imwrite(Path + '/image_eq_ch4.jpg', img_crop_ch4_eq)

cv2.imwrite(Path + '/image_ch5.jpg', img_crop_ch5)
img_crop_ch5_eq = cv2.equalizeHist(img_crop_ch5)
cv2.imwrite(Path + '/image_eq_ch5.jpg', img_crop_ch5_eq)

cv2.imwrite(Path + '/image_ch6.jpg', img_crop_ch6)
img_crop_ch6_eq = cv2.equalizeHist(img_crop_ch6)
cv2.imwrite(Path + '/image_eq_ch6.jpg', img_crop_ch6_eq)
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# True

# %%
img_rgb_merged = cv2.merge((img_crop_ch1_eq, img_crop_ch2_eq, img_crop_ch3_eq))
img_rgb_grayed = cv2.cvtColor(img_rgb_merged, cv2.COLOR_BGR2GRAY)


# This instance merges the six channels back together before saving the chunks
img_merged = cv2.merge((img_rgb_grayed, img_crop_ch4_eq, img_crop_ch5_eq, img_crop_ch6_eq))
#img_merged = cv2.merge((img_crop_ch1_eq, img_crop_ch2_eq, img_crop_ch3_eq, img_crop_ch4_eq, img_crop_ch5_eq, img_crop_ch6_eq))
# Find the dimensions and channels of the image
img_rgb_height, img_rgb_width, img_rgb_channels = img_merged.shape
print("Image height (Pixels):\t", img_rgb_height)
print("Image width (Pixels):\t", img_rgb_width)
print("Image channels:\t\t", img_rgb_channels)
print("----------------------------------")

# Iterate though the maks by chunk_size and sort chunks into directories
for i in range(int((img_height_corrected+1)/chunk_size)):
    for j in range(int((img_width_corrected+1)/chunk_size)):
        counter += 1
        print("Processing square ", counter)
        
        img_mask_tmp = img_mask_crop[(i*chunk_size):(i*chunk_size)+chunk_size, (j*chunk_size):(j*chunk_size)+chunk_size]
        img_rgb_tmp = img_rgb_crop[(i*chunk_size):(i*chunk_size)+chunk_size, (j*chunk_size):(j*chunk_size)+chunk_size]
        
        if img_mask_tmp[int(chunk_size/2), int(chunk_size/2), 0] == 17:
            #tifffile.imsave(Path + '/Field_1/image_' + str(counter) + '.tiff', img_merged[(i*chunk_size):(i*chunk_size)+chunk_size, (j*chunk_size):(j*chunk_size)+chunk_size])
            cv2.imwrite(Path + '/Field_1/image_' + str(counter) + '.jpg', img_merged[(i*chunk_size):(i*chunk_size)+chunk_size, (j*chunk_size):(j*chunk_size)+chunk_size])
            cv2.imwrite(Path + '/Mask_reference/image_' + str(counter) + '.jpg', img_mask_tmp)
            cv2.imwrite(Path + '/RGB_reference/image_' + str(counter) + '_rgb.jpg', img_rgb_tmp)

        if img_mask_tmp[int(chunk_size/2), int(chunk_size/2), 0] == 68:
            #tifffile.imsave(Path + '/Field_2/image_' + str(counter) + '.tiff', img_merged[(i*chunk_size):(i*chunk_size)+chunk_size, (j*chunk_size):(j*chunk_size)+chunk_size])
            cv2.imwrite(Path + '/Field_2/image_' + str(counter) + '.jpg', img_merged[(i*chunk_size):(i*chunk_size)+chunk_size, (j*chunk_size):(j*chunk_size)+chunk_size])
            cv2.imwrite(Path + '/Mask_reference/image_' + str(counter) + '.jpg', img_mask_tmp)
            cv2.imwrite(Path + '/RGB_reference/image_' + str(counter) + '_rgb.jpg', img_rgb_tmp)
        
        if img_mask_tmp[int(chunk_size/2), int(chunk_size/2), 0] == 136:
            #tifffile.imsave(Path + '/Field_3/image_' + str(counter) + '.tiff', img_merged[(i*chunk_size):(i*chunk_size)+chunk_size, (j*chunk_size):(j*chunk_size)+chunk_size])
            cv2.imwrite(Path + '/Field_3/image_' + str(counter) + '.jpg', img_merged[(i*chunk_size):(i*chunk_size)+chunk_size, (j*chunk_size):(j*chunk_size)+chunk_size])
            cv2.imwrite(Path + '/Mask_reference/image_' + str(counter) + '.jpg', img_mask_tmp)
            cv2.imwrite(Path + '/RGB_reference/image_' + str(counter) + '_rgb.jpg', img_rgb_tmp)
        
        if img_mask_tmp[int(chunk_size/2), int(chunk_size/2), 0] == 187:
            #tifffile.imsave(Path + '/Field_4/image_' + str(counter) + '.tiff', img_merged[(i*chunk_size):(i*chunk_size)+chunk_size, (j*chunk_size):(j*chunk_size)+chunk_size])
            cv2.imwrite(Path + '/Field_4/image_' + str(counter) + '.jpg', img_merged[(i*chunk_size):(i*chunk_size)+chunk_size, (j*chunk_size):(j*chunk_size)+chunk_size])
            cv2.imwrite(Path + '/Mask_reference/image_' + str(counter) + '.jpg', img_mask_tmp)
            cv2.imwrite(Path + '/RGB_reference/image_' + str(counter) + '_rgb.jpg', img_rgb_tmp)
            
        
        else:
            print("non-defined chunk, skipped.")
print("Sorting complete.")
# Out:
# Image height (Pixels):	 18175
# Image width (Pixels):	 7167
# Image channels:		 4
# ----------------------------------
# Processing square  1
# non-defined chunk, skipped.
# Processing square  2
# non-defined chunk, skipped.
# Processing square  3
# non-defined chunk, skipped.
# Processing square  4
# non-defined chunk, skipped.
# Processing square  5
# non-defined chunk, skipped.
# Processing square  6
# non-defined chunk, skipped.
# Processing square  7
# non-defined chunk, skipped.
# Processing square  8
# non-defined chunk, skipped.
# Processing square  9
# non-defined chunk, skipped.
# Processing square  10
# non-defined chunk, skipped.
# Processing square  11
# non-defined chunk, skipped.
# Processing square  12
# non-defined chunk, skipped.
# Processing square  13
# non-defined chunk, skipped.
# Processing square  14
# non-defined chunk, skipped.
# Processing square  15
# non-defined chunk, skipped.
# Processing square  16
# non-defined chunk, skipped.
# Processing square  17
# non-defined chunk, skipped.
# Processing square  18
# non-defined chunk, skipped.
# Processing square  19
# non-defined chunk, skipped.
# Processing square  20
# non-defined chunk, skipped.
# Processing square  21
# non-defined chunk, skipped.
# Processing square  22
# non-defined chunk, skipped.
# Processing square  23
# non-defined chunk, skipped.
# Processing square  24
# non-defined chunk, skipped.
# Processing square  25
# non-defined chunk, skipped.
# Processing square  26
# non-defined chunk, skipped.
# Processing square  27
# non-defined chunk, skipped.
# Processing square  28
# non-defined chunk, skipped.
# Processing square  29
# non-defined chunk, skipped.
# Processing square  30
# non-defined chunk, skipped.
# Processing square  31
# non-defined chunk, skipped.
# Processing square  32
# non-defined chunk, skipped.
# Processing square  33
# non-defined chunk, skipped.
# Processing square  34
# non-defined chunk, skipped.
# Processing square  35
# non-defined chunk, skipped.
# Processing square  36
# non-defined chunk, skipped.
# Processing square  37
# non-defined chunk, skipped.
# Processing square  38
# non-defined chunk, skipped.
# Processing square  39
# non-defined chunk, skipped.
# Processing square  40
# non-defined chunk, skipped.
# Processing square  41
# non-defined chunk, skipped.
# Processing square  42
# non-defined chunk, skipped.
# Processing square  43
# non-defined chunk, skipped.
# Processing square  44
# non-defined chunk, skipped.
# Processing square  45
# non-defined chunk, skipped.
# Processing square  46
# non-defined chunk, skipped.
# Processing square  47
# non-defined chunk, skipped.
# Processing square  48
# non-defined chunk, skipped.
# Processing square  49
# non-defined chunk, skipped.
# Processing square  50
# non-defined chunk, skipped.
# Processing square  51
# non-defined chunk, skipped.
# Processing square  52
# non-defined chunk, skipped.
# Processing square  53
# non-defined chunk, skipped.
# Processing square  54
# non-defined chunk, skipped.
# Processing square  55
# non-defined chunk, skipped.
# Processing square  56
# non-defined chunk, skipped.
# Processing square  57
# non-defined chunk, skipped.
# Processing square  58
# non-defined chunk, skipped.
# Processing square  59
# non-defined chunk, skipped.
# Processing square  60
# non-defined chunk, skipped.
# Processing square  61
# non-defined chunk, skipped.
# Processing square  62
# non-defined chunk, skipped.
# Processing square  63
# non-defined chunk, skipped.
# Processing square  64
# non-defined chunk, skipped.
# Processing square  65
# non-defined chunk, skipped.
# Processing square  66
# non-defined chunk, skipped.
# Processing square  67
# non-defined chunk, skipped.
# Processing square  68
# non-defined chunk, skipped.
# Processing square  69
# non-defined chunk, skipped.
# Processing square  70
# non-defined chunk, skipped.
# Processing square  71
# non-defined chunk, skipped.
# Processing square  72
# non-defined chunk, skipped.
# Processing square  73
# non-defined chunk, skipped.
# Processing square  74
# non-defined chunk, skipped.
# Processing square  75
# non-defined chunk, skipped.
# Processing square  76
# non-defined chunk, skipped.
# Processing square  77
# non-defined chunk, skipped.
# Processing square  78
# non-defined chunk, skipped.
# Processing square  79
# non-defined chunk, skipped.
# Processing square  80
# non-defined chunk, skipped.
# Processing square  81
# non-defined chunk, skipped.
# Processing square  82
# non-defined chunk, skipped.
# Processing square  83
# non-defined chunk, skipped.
# Processing square  84
# non-defined chunk, skipped.
# Processing square  85
# non-defined chunk, skipped.
# Processing square  86
# non-defined chunk, skipped.
# Processing square  87
# non-defined chunk, skipped.
# Processing square  88
# non-defined chunk, skipped.
# Processing square  89
# non-defined chunk, skipped.
# Processing square  90
# non-defined chunk, skipped.
# Processing square  91
# non-defined chunk, skipped.
# Processing square  92
# non-defined chunk, skipped.
# Processing square  93
# non-defined chunk, skipped.
# Processing square  94
# non-defined chunk, skipped.
# Processing square  95
# non-defined chunk, skipped.
# Processing square  96
# non-defined chunk, skipped.
# Processing square  97
# non-defined chunk, skipped.
# Processing square  98
# non-defined chunk, skipped.
# Processing square  99
# non-defined chunk, skipped.
# Processing square  100
# non-defined chunk, skipped.
# Processing square  101
# non-defined chunk, skipped.
# Processing square  102
# non-defined chunk, skipped.
# Processing square  103
# non-defined chunk, skipped.
# Processing square  104
# non-defined chunk, skipped.
# Processing square  105
# non-defined chunk, skipped.
# Processing square  106
# non-defined chunk, skipped.
# Processing square  107
# non-defined chunk, skipped.
# Processing square  108
# non-defined chunk, skipped.
# Processing square  109
# non-defined chunk, skipped.
# Processing square  110
# non-defined chunk, skipped.
# Processing square  111
# non-defined chunk, skipped.
# Processing square  112
# non-defined chunk, skipped.
# Processing square  113
# non-defined chunk, skipped.
# Processing square  114
# non-defined chunk, skipped.
# Processing square  115
# non-defined chunk, skipped.
# Processing square  116
# non-defined chunk, skipped.
# Processing square  117
# non-defined chunk, skipped.
# Processing square  118
# non-defined chunk, skipped.
# Processing square  119
# non-defined chunk, skipped.
# Processing square  120
# non-defined chunk, skipped.
# Processing square  121
# non-defined chunk, skipped.
# Processing square  122
# non-defined chunk, skipped.
# Processing square  123
# non-defined chunk, skipped.
# Processing square  124
# non-defined chunk, skipped.
# Processing square  125
# non-defined chunk, skipped.
# Processing square  126
# non-defined chunk, skipped.
# Processing square  127
# non-defined chunk, skipped.
# Processing square  128
# non-defined chunk, skipped.
# Processing square  129
# non-defined chunk, skipped.
# Processing square  130
# non-defined chunk, skipped.
# Processing square  131
# non-defined chunk, skipped.
# Processing square  132
# non-defined chunk, skipped.
# Processing square  133
# non-defined chunk, skipped.
# Processing square  134
# non-defined chunk, skipped.
# Processing square  135
# non-defined chunk, skipped.
# Processing square  136
# non-defined chunk, skipped.
# Processing square  137
# non-defined chunk, skipped.
# Processing square  138
# non-defined chunk, skipped.
# Processing square  139
# non-defined chunk, skipped.
# Processing square  140
# non-defined chunk, skipped.
# Processing square  141
# non-defined chunk, skipped.
# Processing square  142
# non-defined chunk, skipped.
# Processing square  143
# non-defined chunk, skipped.
# Processing square  144
# non-defined chunk, skipped.
# Processing square  145
# non-defined chunk, skipped.
# Processing square  146
# non-defined chunk, skipped.
# Processing square  147
# non-defined chunk, skipped.
# Processing square  148
# non-defined chunk, skipped.
# Processing square  149
# non-defined chunk, skipped.
# Processing square  150
# non-defined chunk, skipped.
# Processing square  151
# non-defined chunk, skipped.
# Processing square  152
# non-defined chunk, skipped.
# Processing square  153
# non-defined chunk, skipped.
# Processing square  154
# non-defined chunk, skipped.
# Processing square  155
# non-defined chunk, skipped.
# Processing square  156
# non-defined chunk, skipped.
# Processing square  157
# non-defined chunk, skipped.
# Processing square  158
# non-defined chunk, skipped.
# Processing square  159
# non-defined chunk, skipped.
# Processing square  160
# non-defined chunk, skipped.
# Processing square  161
# non-defined chunk, skipped.
# Processing square  162
# non-defined chunk, skipped.
# Processing square  163
# non-defined chunk, skipped.
# Processing square  164
# non-defined chunk, skipped.
# Processing square  165
# non-defined chunk, skipped.
# Processing square  166
# non-defined chunk, skipped.
# Processing square  167
# non-defined chunk, skipped.
# Processing square  168
# non-defined chunk, skipped.
# Processing square  169
# non-defined chunk, skipped.
# Processing square  170
# non-defined chunk, skipped.
# Processing square  171
# non-defined chunk, skipped.
# Processing square  172
# non-defined chunk, skipped.
# Processing square  173
# non-defined chunk, skipped.
# Processing square  174
# non-defined chunk, skipped.
# Processing square  175
# non-defined chunk, skipped.
# Processing square  176
# non-defined chunk, skipped.
# Processing square  177
# non-defined chunk, skipped.
# Processing square  178
# non-defined chunk, skipped.
# Processing square  179
# non-defined chunk, skipped.
# Processing square  180
# non-defined chunk, skipped.
# Processing square  181
# non-defined chunk, skipped.
# Processing square  182
# non-defined chunk, skipped.
# Processing square  183
# non-defined chunk, skipped.
# Processing square  184
# non-defined chunk, skipped.
# Processing square  185
# non-defined chunk, skipped.
# Processing square  186
# non-defined chunk, skipped.
# Processing square  187
# non-defined chunk, skipped.
# Processing square  188
# non-defined chunk, skipped.
# Processing square  189
# non-defined chunk, skipped.
# Processing square  190
# non-defined chunk, skipped.
# Processing square  191
# non-defined chunk, skipped.
# Processing square  192
# non-defined chunk, skipped.
# Processing square  193
# non-defined chunk, skipped.
# Processing square  194
# non-defined chunk, skipped.
# Processing square  195
# non-defined chunk, skipped.
# Processing square  196
# non-defined chunk, skipped.
# Processing square  197
# non-defined chunk, skipped.
# Processing square  198
# non-defined chunk, skipped.
# Processing square  199
# non-defined chunk, skipped.
# Processing square  200
# non-defined chunk, skipped.
# Processing square  201
# non-defined chunk, skipped.
# Processing square  202
# non-defined chunk, skipped.
# Processing square  203
# non-defined chunk, skipped.
# Processing square  204
# non-defined chunk, skipped.
# Processing square  205
# non-defined chunk, skipped.
# Processing square  206
# non-defined chunk, skipped.
# Processing square  207
# non-defined chunk, skipped.
# Processing square  208
# non-defined chunk, skipped.
# Processing square  209
# non-defined chunk, skipped.
# Processing square  210
# non-defined chunk, skipped.
# Processing square  211
# non-defined chunk, skipped.
# Processing square  212
# non-defined chunk, skipped.
# Processing square  213
# non-defined chunk, skipped.
# Processing square  214
# non-defined chunk, skipped.
# Processing square  215
# non-defined chunk, skipped.
# Processing square  216
# non-defined chunk, skipped.
# Processing square  217
# non-defined chunk, skipped.
# Processing square  218
# non-defined chunk, skipped.
# Processing square  219
# non-defined chunk, skipped.
# Processing square  220
# non-defined chunk, skipped.
# Processing square  221
# non-defined chunk, skipped.
# Processing square  222
# non-defined chunk, skipped.
# Processing square  223
# non-defined chunk, skipped.
# Processing square  224
# non-defined chunk, skipped.
# Processing square  225
# non-defined chunk, skipped.
# Processing square  226
# non-defined chunk, skipped.
# Processing square  227
# non-defined chunk, skipped.
# Processing square  228
# non-defined chunk, skipped.
# Processing square  229
# non-defined chunk, skipped.
# Processing square  230
# non-defined chunk, skipped.
# Processing square  231
# non-defined chunk, skipped.
# Processing square  232
# non-defined chunk, skipped.
# Processing square  233
# non-defined chunk, skipped.
# Processing square  234
# non-defined chunk, skipped.
# Processing square  235
# non-defined chunk, skipped.
# Processing square  236
# non-defined chunk, skipped.
# Processing square  237
# non-defined chunk, skipped.
# Processing square  238
# non-defined chunk, skipped.
# Processing square  239
# non-defined chunk, skipped.
# Processing square  240
# non-defined chunk, skipped.
# Processing square  241
# non-defined chunk, skipped.
# Processing square  242
# non-defined chunk, skipped.
# Processing square  243
# non-defined chunk, skipped.
# Processing square  244
# non-defined chunk, skipped.
# Processing square  245
# non-defined chunk, skipped.
# Processing square  246
# non-defined chunk, skipped.
# Processing square  247
# non-defined chunk, skipped.
# Processing square  248
# non-defined chunk, skipped.
# Processing square  249
# non-defined chunk, skipped.
# Processing square  250
# non-defined chunk, skipped.
# Processing square  251
# non-defined chunk, skipped.
# Processing square  252
# non-defined chunk, skipped.
# Processing square  253
# non-defined chunk, skipped.
# Processing square  254
# non-defined chunk, skipped.
# Processing square  255
# non-defined chunk, skipped.
# Processing square  256
# non-defined chunk, skipped.
# Processing square  257
# non-defined chunk, skipped.
# Processing square  258
# non-defined chunk, skipped.
# Processing square  259
# non-defined chunk, skipped.
# Processing square  260
# non-defined chunk, skipped.
# Processing square  261
# non-defined chunk, skipped.
# Processing square  262
# non-defined chunk, skipped.
# Processing square  263
# non-defined chunk, skipped.
# Processing square  264
# non-defined chunk, skipped.
# Processing square  265
# non-defined chunk, skipped.
# Processing square  266
# non-defined chunk, skipped.
# Processing square  267
# non-defined chunk, skipped.
# Processing square  268
# non-defined chunk, skipped.
# Processing square  269
# non-defined chunk, skipped.
# Processing square  270
# non-defined chunk, skipped.
# Processing square  271
# non-defined chunk, skipped.
# Processing square  272
# non-defined chunk, skipped.
# Processing square  273
# non-defined chunk, skipped.
# Processing square  274
# non-defined chunk, skipped.
# Processing square  275
# non-defined chunk, skipped.
# Processing square  276
# non-defined chunk, skipped.
# Processing square  277
# non-defined chunk, skipped.
# Processing square  278
# non-defined chunk, skipped.
# Processing square  279
# non-defined chunk, skipped.
# Processing square  280
# non-defined chunk, skipped.
# Processing square  281
# non-defined chunk, skipped.
# Processing square  282
# non-defined chunk, skipped.
# Processing square  283
# non-defined chunk, skipped.
# Processing square  284
# non-defined chunk, skipped.
# Processing square  285
# non-defined chunk, skipped.
# Processing square  286
# non-defined chunk, skipped.
# Processing square  287
# non-defined chunk, skipped.
# Processing square  288
# non-defined chunk, skipped.
# Processing square  289
# non-defined chunk, skipped.
# Processing square  290
# non-defined chunk, skipped.
# Processing square  291
# non-defined chunk, skipped.
# Processing square  292
# non-defined chunk, skipped.
# Processing square  293
# non-defined chunk, skipped.
# Processing square  294
# non-defined chunk, skipped.
# Processing square  295
# non-defined chunk, skipped.
# Processing square  296
# non-defined chunk, skipped.
# Processing square  297
# non-defined chunk, skipped.
# Processing square  298
# non-defined chunk, skipped.
# Processing square  299
# non-defined chunk, skipped.
# Processing square  300
# non-defined chunk, skipped.
# Processing square  301
# non-defined chunk, skipped.
# Processing square  302
# non-defined chunk, skipped.
# Processing square  303
# non-defined chunk, skipped.
# Processing square  304
# non-defined chunk, skipped.
# Processing square  305
# non-defined chunk, skipped.
# Processing square  306
# non-defined chunk, skipped.
# Processing square  307
# non-defined chunk, skipped.
# Processing square  308
# non-defined chunk, skipped.
# Processing square  309
# non-defined chunk, skipped.
# Processing square  310
# non-defined chunk, skipped.
# Processing square  311
# non-defined chunk, skipped.
# Processing square  312
# non-defined chunk, skipped.
# Processing square  313
# non-defined chunk, skipped.
# Processing square  314
# non-defined chunk, skipped.
# Processing square  315
# non-defined chunk, skipped.
# Processing square  316
# non-defined chunk, skipped.
# Processing square  317
# non-defined chunk, skipped.
# Processing square  318
# non-defined chunk, skipped.
# Processing square  319
# non-defined chunk, skipped.
# Processing square  320
# non-defined chunk, skipped.
# Processing square  321
# non-defined chunk, skipped.
# Processing square  322
# non-defined chunk, skipped.
# Processing square  323
# non-defined chunk, skipped.
# Processing square  324
# non-defined chunk, skipped.
# Processing square  325
# non-defined chunk, skipped.
# Processing square  326
# non-defined chunk, skipped.
# Processing square  327
# non-defined chunk, skipped.
# Processing square  328
# non-defined chunk, skipped.
# Processing square  329
# non-defined chunk, skipped.
# Processing square  330
# non-defined chunk, skipped.
# Processing square  331
# non-defined chunk, skipped.
# Processing square  332
# non-defined chunk, skipped.
# Processing square  333
# non-defined chunk, skipped.
# Processing square  334
# non-defined chunk, skipped.
# Processing square  335
# non-defined chunk, skipped.
# Processing square  336
# non-defined chunk, skipped.
# Processing square  337
# non-defined chunk, skipped.
# Processing square  338
# non-defined chunk, skipped.
# Processing square  339
# non-defined chunk, skipped.
# Processing square  340
# non-defined chunk, skipped.
# Processing square  341
# non-defined chunk, skipped.
# Processing square  342
# non-defined chunk, skipped.
# Processing square  343
# non-defined chunk, skipped.
# Processing square  344
# non-defined chunk, skipped.
# Processing square  345
# non-defined chunk, skipped.
# Processing square  346
# non-defined chunk, skipped.
# Processing square  347
# non-defined chunk, skipped.
# Processing square  348
# non-defined chunk, skipped.
# Processing square  349
# non-defined chunk, skipped.
# Processing square  350
# non-defined chunk, skipped.
# Processing square  351
# non-defined chunk, skipped.
# Processing square  352
# non-defined chunk, skipped.
# Processing square  353
# non-defined chunk, skipped.
# Processing square  354
# non-defined chunk, skipped.
# Processing square  355
# non-defined chunk, skipped.
# Processing square  356
# non-defined chunk, skipped.
# Processing square  357
# non-defined chunk, skipped.
# Processing square  358
# non-defined chunk, skipped.
# Processing square  359
# non-defined chunk, skipped.
# Processing square  360
# non-defined chunk, skipped.
# Processing square  361
# non-defined chunk, skipped.
# Processing square  362
# non-defined chunk, skipped.
# Processing square  363
# non-defined chunk, skipped.
# Processing square  364
# non-defined chunk, skipped.
# Processing square  365
# non-defined chunk, skipped.
# Processing square  366
# non-defined chunk, skipped.
# Processing square  367
# non-defined chunk, skipped.
# Processing square  368
# non-defined chunk, skipped.
# Processing square  369
# non-defined chunk, skipped.
# Processing square  370
# non-defined chunk, skipped.
# Processing square  371
# non-defined chunk, skipped.
# Processing square  372
# non-defined chunk, skipped.
# Processing square  373
# non-defined chunk, skipped.
# Processing square  374
# non-defined chunk, skipped.
# Processing square  375
# non-defined chunk, skipped.
# Processing square  376
# non-defined chunk, skipped.
# Processing square  377
# non-defined chunk, skipped.
# Processing square  378
# non-defined chunk, skipped.
# Processing square  379
# non-defined chunk, skipped.
# Processing square  380
# non-defined chunk, skipped.
# Processing square  381
# non-defined chunk, skipped.
# Processing square  382
# non-defined chunk, skipped.
# Processing square  383
# non-defined chunk, skipped.
# Processing square  384
# non-defined chunk, skipped.
# Processing square  385
# non-defined chunk, skipped.
# Processing square  386
# non-defined chunk, skipped.
# Processing square  387
# non-defined chunk, skipped.
# Processing square  388
# non-defined chunk, skipped.
# Processing square  389
# non-defined chunk, skipped.
# Processing square  390
# non-defined chunk, skipped.
# Processing square  391
# non-defined chunk, skipped.
# Processing square  392
# non-defined chunk, skipped.
# Processing square  393
# non-defined chunk, skipped.
# Processing square  394
# non-defined chunk, skipped.
# Processing square  395
# non-defined chunk, skipped.
# Processing square  396
# non-defined chunk, skipped.
# Processing square  397
# non-defined chunk, skipped.
# Processing square  398
# non-defined chunk, skipped.
# Processing square  399
# non-defined chunk, skipped.
# Processing square  400
# non-defined chunk, skipped.
# Processing square  401
# non-defined chunk, skipped.
# Processing square  402
# non-defined chunk, skipped.
# Processing square  403
# non-defined chunk, skipped.
# Processing square  404
# non-defined chunk, skipped.
# Processing square  405
# non-defined chunk, skipped.
# Processing square  406
# non-defined chunk, skipped.
# Processing square  407
# non-defined chunk, skipped.
# Processing square  408
# non-defined chunk, skipped.
# Processing square  409
# non-defined chunk, skipped.
# Processing square  410
# non-defined chunk, skipped.
# Processing square  411
# non-defined chunk, skipped.
# Processing square  412
# non-defined chunk, skipped.
# Processing square  413
# non-defined chunk, skipped.
# Processing square  414
# non-defined chunk, skipped.
# Processing square  415
# non-defined chunk, skipped.
# Processing square  416
# non-defined chunk, skipped.
# Processing square  417
# non-defined chunk, skipped.
# Processing square  418
# non-defined chunk, skipped.
# Processing square  419
# non-defined chunk, skipped.
# Processing square  420
# non-defined chunk, skipped.
# Processing square  421
# non-defined chunk, skipped.
# Processing square  422
# non-defined chunk, skipped.
# Processing square  423
# non-defined chunk, skipped.
# Processing square  424
# non-defined chunk, skipped.
# Processing square  425
# non-defined chunk, skipped.
# Processing square  426
# non-defined chunk, skipped.
# Processing square  427
# non-defined chunk, skipped.
# Processing square  428
# non-defined chunk, skipped.
# Processing square  429
# non-defined chunk, skipped.
# Processing square  430
# non-defined chunk, skipped.
# Processing square  431
# non-defined chunk, skipped.
# Processing square  432
# non-defined chunk, skipped.
# Processing square  433
# non-defined chunk, skipped.
# Processing square  434
# non-defined chunk, skipped.
# Processing square  435
# non-defined chunk, skipped.
# Processing square  436
# non-defined chunk, skipped.
# Processing square  437
# non-defined chunk, skipped.
# Processing square  438
# non-defined chunk, skipped.
# Processing square  439
# non-defined chunk, skipped.
# Processing square  440
# non-defined chunk, skipped.
# Processing square  441
# non-defined chunk, skipped.
# Processing square  442
# non-defined chunk, skipped.
# Processing square  443
# non-defined chunk, skipped.
# Processing square  444
# non-defined chunk, skipped.
# Processing square  445
# non-defined chunk, skipped.
# Processing square  446
# non-defined chunk, skipped.
# Processing square  447
# non-defined chunk, skipped.
# Processing square  448
# non-defined chunk, skipped.
# Processing square  449
# non-defined chunk, skipped.
# Processing square  450
# non-defined chunk, skipped.
# Processing square  451
# non-defined chunk, skipped.
# Processing square  452
# non-defined chunk, skipped.
# Processing square  453
# non-defined chunk, skipped.
# Processing square  454
# non-defined chunk, skipped.
# Processing square  455
# non-defined chunk, skipped.
# Processing square  456
# non-defined chunk, skipped.
# Processing square  457
# non-defined chunk, skipped.
# Processing square  458
# non-defined chunk, skipped.
# Processing square  459
# non-defined chunk, skipped.
# Processing square  460
# non-defined chunk, skipped.
# Processing square  461
# non-defined chunk, skipped.
# Processing square  462
# non-defined chunk, skipped.
# Processing square  463
# non-defined chunk, skipped.
# Processing square  464
# non-defined chunk, skipped.
# Processing square  465
# non-defined chunk, skipped.
# Processing square  466
# non-defined chunk, skipped.
# Processing square  467
# non-defined chunk, skipped.
# Processing square  468
# non-defined chunk, skipped.
# Processing square  469
# non-defined chunk, skipped.
# Processing square  470
# non-defined chunk, skipped.
# Processing square  471
# non-defined chunk, skipped.
# Processing square  472
# non-defined chunk, skipped.
# Processing square  473
# non-defined chunk, skipped.
# Processing square  474
# non-defined chunk, skipped.
# Processing square  475
# non-defined chunk, skipped.
# Processing square  476
# non-defined chunk, skipped.
# Processing square  477
# non-defined chunk, skipped.
# Processing square  478
# non-defined chunk, skipped.
# Processing square  479
# non-defined chunk, skipped.
# Processing square  480
# non-defined chunk, skipped.
# Processing square  481
# non-defined chunk, skipped.
# Processing square  482
# non-defined chunk, skipped.
# Processing square  483
# non-defined chunk, skipped.
# Processing square  484
# non-defined chunk, skipped.
# Processing square  485
# non-defined chunk, skipped.
# Processing square  486
# non-defined chunk, skipped.
# Processing square  487
# non-defined chunk, skipped.
# Processing square  488
# non-defined chunk, skipped.
# Processing square  489
# non-defined chunk, skipped.
# Processing square  490
# non-defined chunk, skipped.
# Processing square  491
# non-defined chunk, skipped.
# Processing square  492
# non-defined chunk, skipped.
# Processing square  493
# non-defined chunk, skipped.
# Processing square  494
# non-defined chunk, skipped.
# Processing square  495
# non-defined chunk, skipped.
# Processing square  496
# non-defined chunk, skipped.
# Processing square  497
# non-defined chunk, skipped.
# Processing square  498
# non-defined chunk, skipped.
# Processing square  499
# non-defined chunk, skipped.
# Processing square  500
# non-defined chunk, skipped.
# Processing square  501
# non-defined chunk, skipped.
# Processing square  502
# non-defined chunk, skipped.
# Processing square  503
# non-defined chunk, skipped.
# Processing square  504
# non-defined chunk, skipped.
# Processing square  505
# non-defined chunk, skipped.
# Processing square  506
# non-defined chunk, skipped.
# Processing square  507
# non-defined chunk, skipped.
# Processing square  508
# non-defined chunk, skipped.
# Processing square  509
# non-defined chunk, skipped.
# Processing square  510
# non-defined chunk, skipped.
# Processing square  511
# non-defined chunk, skipped.
# Processing square  512
# non-defined chunk, skipped.
# Processing square  513
# non-defined chunk, skipped.
# Processing square  514
# non-defined chunk, skipped.
# Processing square  515
# non-defined chunk, skipped.
# Processing square  516
# non-defined chunk, skipped.
# Processing square  517
# non-defined chunk, skipped.
# Processing square  518
# non-defined chunk, skipped.
# Processing square  519
# non-defined chunk, skipped.
# Processing square  520
# non-defined chunk, skipped.
# Processing square  521
# non-defined chunk, skipped.
# Processing square  522
# non-defined chunk, skipped.
# Processing square  523
# non-defined chunk, skipped.
# Processing square  524
# non-defined chunk, skipped.
# Processing square  525
# non-defined chunk, skipped.
# Processing square  526
# non-defined chunk, skipped.
# Processing square  527
# non-defined chunk, skipped.
# Processing square  528
# non-defined chunk, skipped.
# Processing square  529
# non-defined chunk, skipped.
# Processing square  530
# non-defined chunk, skipped.
# Processing square  531
# non-defined chunk, skipped.
# Processing square  532
# non-defined chunk, skipped.
# Processing square  533
# non-defined chunk, skipped.
# Processing square  534
# non-defined chunk, skipped.
# Processing square  535
# non-defined chunk, skipped.
# Processing square  536
# non-defined chunk, skipped.
# Processing square  537
# non-defined chunk, skipped.
# Processing square  538
# non-defined chunk, skipped.
# Processing square  539
# non-defined chunk, skipped.
# Processing square  540
# non-defined chunk, skipped.
# Processing square  541
# non-defined chunk, skipped.
# Processing square  542
# non-defined chunk, skipped.
# Processing square  543
# non-defined chunk, skipped.
# Processing square  544
# non-defined chunk, skipped.
# Processing square  545
# non-defined chunk, skipped.
# Processing square  546
# non-defined chunk, skipped.
# Processing square  547
# non-defined chunk, skipped.
# Processing square  548
# non-defined chunk, skipped.
# Processing square  549
# non-defined chunk, skipped.
# Processing square  550
# non-defined chunk, skipped.
# Processing square  551
# non-defined chunk, skipped.
# Processing square  552
# non-defined chunk, skipped.
# Processing square  553
# non-defined chunk, skipped.
# Processing square  554
# non-defined chunk, skipped.
# Processing square  555
# non-defined chunk, skipped.
# Processing square  556
# non-defined chunk, skipped.
# Processing square  557
# non-defined chunk, skipped.
# Processing square  558
# non-defined chunk, skipped.
# Processing square  559
# non-defined chunk, skipped.
# Processing square  560
# non-defined chunk, skipped.
# Processing square  561
# non-defined chunk, skipped.
# Processing square  562
# non-defined chunk, skipped.
# Processing square  563
# non-defined chunk, skipped.
# Processing square  564
# non-defined chunk, skipped.
# Processing square  565
# non-defined chunk, skipped.
# Processing square  566
# non-defined chunk, skipped.
# Processing square  567
# non-defined chunk, skipped.
# Processing square  568
# non-defined chunk, skipped.
# Processing square  569
# non-defined chunk, skipped.
# Processing square  570
# non-defined chunk, skipped.
# Processing square  571
# non-defined chunk, skipped.
# Processing square  572
# non-defined chunk, skipped.
# Processing square  573
# non-defined chunk, skipped.
# Processing square  574
# non-defined chunk, skipped.
# Processing square  575
# non-defined chunk, skipped.
# Processing square  576
# non-defined chunk, skipped.
# Processing square  577
# non-defined chunk, skipped.
# Processing square  578
# non-defined chunk, skipped.
# Processing square  579
# non-defined chunk, skipped.
# Processing square  580
# non-defined chunk, skipped.
# Processing square  581
# non-defined chunk, skipped.
# Processing square  582
# non-defined chunk, skipped.
# Processing square  583
# non-defined chunk, skipped.
# Processing square  584
# non-defined chunk, skipped.
# Processing square  585
# non-defined chunk, skipped.
# Processing square  586
# non-defined chunk, skipped.
# Processing square  587
# non-defined chunk, skipped.
# Processing square  588
# non-defined chunk, skipped.
# Processing square  589
# non-defined chunk, skipped.
# Processing square  590
# non-defined chunk, skipped.
# Processing square  591
# non-defined chunk, skipped.
# Processing square  592
# non-defined chunk, skipped.
# Processing square  593
# non-defined chunk, skipped.
# Processing square  594
# non-defined chunk, skipped.
# Processing square  595
# non-defined chunk, skipped.
# Processing square  596
# non-defined chunk, skipped.
# Processing square  597
# non-defined chunk, skipped.
# Processing square  598
# non-defined chunk, skipped.
# Processing square  599
# non-defined chunk, skipped.
# Processing square  600
# non-defined chunk, skipped.
# Processing square  601
# non-defined chunk, skipped.
# Processing square  602
# non-defined chunk, skipped.
# Processing square  603
# non-defined chunk, skipped.
# Processing square  604
# non-defined chunk, skipped.
# Processing square  605
# non-defined chunk, skipped.
# Processing square  606
# non-defined chunk, skipped.
# Processing square  607
# non-defined chunk, skipped.
# Processing square  608
# non-defined chunk, skipped.
# Processing square  609
# non-defined chunk, skipped.
# Processing square  610
# non-defined chunk, skipped.
# Processing square  611
# non-defined chunk, skipped.
# Processing square  612
# non-defined chunk, skipped.
# Processing square  613
# non-defined chunk, skipped.
# Processing square  614
# non-defined chunk, skipped.
# Processing square  615
# non-defined chunk, skipped.
# Processing square  616
# non-defined chunk, skipped.
# Processing square  617
# non-defined chunk, skipped.
# Processing square  618
# non-defined chunk, skipped.
# Processing square  619
# non-defined chunk, skipped.
# Processing square  620
# non-defined chunk, skipped.
# Processing square  621
# non-defined chunk, skipped.
# Processing square  622
# non-defined chunk, skipped.
# Processing square  623
# non-defined chunk, skipped.
# Processing square  624
# non-defined chunk, skipped.
# Processing square  625
# non-defined chunk, skipped.
# Processing square  626
# non-defined chunk, skipped.
# Processing square  627
# non-defined chunk, skipped.
# Processing square  628
# non-defined chunk, skipped.
# Processing square  629
# non-defined chunk, skipped.
# Processing square  630
# non-defined chunk, skipped.
# Processing square  631
# non-defined chunk, skipped.
# Processing square  632
# non-defined chunk, skipped.
# Processing square  633
# non-defined chunk, skipped.
# Processing square  634
# non-defined chunk, skipped.
# Processing square  635
# non-defined chunk, skipped.
# Processing square  636
# non-defined chunk, skipped.
# Processing square  637
# non-defined chunk, skipped.
# Processing square  638
# non-defined chunk, skipped.
# Processing square  639
# non-defined chunk, skipped.
# Processing square  640
# non-defined chunk, skipped.
# Processing square  641
# non-defined chunk, skipped.
# Processing square  642
# non-defined chunk, skipped.
# Processing square  643
# non-defined chunk, skipped.
# Processing square  644
# non-defined chunk, skipped.
# Processing square  645
# non-defined chunk, skipped.
# Processing square  646
# non-defined chunk, skipped.
# Processing square  647
# non-defined chunk, skipped.
# Processing square  648
# non-defined chunk, skipped.
# Processing square  649
# non-defined chunk, skipped.
# Processing square  650
# non-defined chunk, skipped.
# Processing square  651
# non-defined chunk, skipped.
# Processing square  652
# non-defined chunk, skipped.
# Processing square  653
# non-defined chunk, skipped.
# Processing square  654
# non-defined chunk, skipped.
# Processing square  655
# non-defined chunk, skipped.
# Processing square  656
# non-defined chunk, skipped.
# Processing square  657
# non-defined chunk, skipped.
# Processing square  658
# non-defined chunk, skipped.
# Processing square  659
# non-defined chunk, skipped.
# Processing square  660
# non-defined chunk, skipped.
# Processing square  661
# non-defined chunk, skipped.
# Processing square  662
# non-defined chunk, skipped.
# Processing square  663
# non-defined chunk, skipped.
# Processing square  664
# non-defined chunk, skipped.
# Processing square  665
# non-defined chunk, skipped.
# Processing square  666
# non-defined chunk, skipped.
# Processing square  667
# non-defined chunk, skipped.
# Processing square  668
# non-defined chunk, skipped.
# Processing square  669
# non-defined chunk, skipped.
# Processing square  670
# non-defined chunk, skipped.
# Processing square  671
# non-defined chunk, skipped.
# Processing square  672
# non-defined chunk, skipped.
# Processing square  673
# non-defined chunk, skipped.
# Processing square  674
# non-defined chunk, skipped.
# Processing square  675
# non-defined chunk, skipped.
# Processing square  676
# non-defined chunk, skipped.
# Processing square  677
# non-defined chunk, skipped.
# Processing square  678
# non-defined chunk, skipped.
# Processing square  679
# non-defined chunk, skipped.
# Processing square  680
# non-defined chunk, skipped.
# Processing square  681
# non-defined chunk, skipped.
# Processing square  682
# non-defined chunk, skipped.
# Processing square  683
# non-defined chunk, skipped.
# Processing square  684
# non-defined chunk, skipped.
# Processing square  685
# non-defined chunk, skipped.
# Processing square  686
# non-defined chunk, skipped.
# Processing square  687
# non-defined chunk, skipped.
# Processing square  688
# non-defined chunk, skipped.
# Processing square  689
# non-defined chunk, skipped.
# Processing square  690
# non-defined chunk, skipped.
# Processing square  691
# non-defined chunk, skipped.
# Processing square  692
# non-defined chunk, skipped.
# Processing square  693
# non-defined chunk, skipped.
# Processing square  694
# non-defined chunk, skipped.
# Processing square  695
# non-defined chunk, skipped.
# Processing square  696
# non-defined chunk, skipped.
# Processing square  697
# non-defined chunk, skipped.
# Processing square  698
# non-defined chunk, skipped.
# Processing square  699
# non-defined chunk, skipped.
# Processing square  700
# non-defined chunk, skipped.
# Processing square  701
# non-defined chunk, skipped.
# Processing square  702
# non-defined chunk, skipped.
# Processing square  703
# non-defined chunk, skipped.
# Processing square  704
# non-defined chunk, skipped.
# Processing square  705
# non-defined chunk, skipped.
# Processing square  706
# non-defined chunk, skipped.
# Processing square  707
# non-defined chunk, skipped.
# Processing square  708
# non-defined chunk, skipped.
# Processing square  709
# non-defined chunk, skipped.
# Processing square  710
# non-defined chunk, skipped.
# Processing square  711
# non-defined chunk, skipped.
# Processing square  712
# non-defined chunk, skipped.
# Processing square  713
# non-defined chunk, skipped.
# Processing square  714
# non-defined chunk, skipped.
# Processing square  715
# non-defined chunk, skipped.
# Processing square  716
# non-defined chunk, skipped.
# Processing square  717
# non-defined chunk, skipped.
# Processing square  718
# non-defined chunk, skipped.
# Processing square  719
# non-defined chunk, skipped.
# Processing square  720
# non-defined chunk, skipped.
# Processing square  721
# non-defined chunk, skipped.
# Processing square  722
# non-defined chunk, skipped.
# Processing square  723
# non-defined chunk, skipped.
# Processing square  724
# non-defined chunk, skipped.
# Processing square  725
# non-defined chunk, skipped.
# Processing square  726
# non-defined chunk, skipped.
# Processing square  727
# non-defined chunk, skipped.
# Processing square  728
# non-defined chunk, skipped.
# Processing square  729
# non-defined chunk, skipped.
# Processing square  730
# non-defined chunk, skipped.
# Processing square  731
# non-defined chunk, skipped.
# Processing square  732
# non-defined chunk, skipped.
# Processing square  733
# non-defined chunk, skipped.
# Processing square  734
# non-defined chunk, skipped.
# Processing square  735
# non-defined chunk, skipped.
# Processing square  736
# non-defined chunk, skipped.
# Processing square  737
# non-defined chunk, skipped.
# Processing square  738
# non-defined chunk, skipped.
# Processing square  739
# non-defined chunk, skipped.
# Processing square  740
# non-defined chunk, skipped.
# Processing square  741
# non-defined chunk, skipped.
# Processing square  742
# non-defined chunk, skipped.
# Processing square  743
# non-defined chunk, skipped.
# Processing square  744
# non-defined chunk, skipped.
# Processing square  745
# non-defined chunk, skipped.
# Processing square  746
# non-defined chunk, skipped.
# Processing square  747
# non-defined chunk, skipped.
# Processing square  748
# non-defined chunk, skipped.
# Processing square  749
# non-defined chunk, skipped.
# Processing square  750
# non-defined chunk, skipped.
# Processing square  751
# non-defined chunk, skipped.
# Processing square  752
# non-defined chunk, skipped.
# Processing square  753
# non-defined chunk, skipped.
# Processing square  754
# non-defined chunk, skipped.
# Processing square  755
# non-defined chunk, skipped.
# Processing square  756
# non-defined chunk, skipped.
# Processing square  757
# non-defined chunk, skipped.
# Processing square  758
# non-defined chunk, skipped.
# Processing square  759
# non-defined chunk, skipped.
# Processing square  760
# non-defined chunk, skipped.
# Processing square  761
# non-defined chunk, skipped.
# Processing square  762
# non-defined chunk, skipped.
# Processing square  763
# non-defined chunk, skipped.
# Processing square  764
# non-defined chunk, skipped.
# Processing square  765
# non-defined chunk, skipped.
# Processing square  766
# non-defined chunk, skipped.
# Processing square  767
# non-defined chunk, skipped.
# Processing square  768
# non-defined chunk, skipped.
# Processing square  769
# non-defined chunk, skipped.
# Processing square  770
# non-defined chunk, skipped.
# Processing square  771
# non-defined chunk, skipped.
# Processing square  772
# non-defined chunk, skipped.
# Processing square  773
# non-defined chunk, skipped.
# Processing square  774
# non-defined chunk, skipped.
# Processing square  775
# non-defined chunk, skipped.
# Processing square  776
# non-defined chunk, skipped.
# Processing square  777
# non-defined chunk, skipped.
# Processing square  778
# non-defined chunk, skipped.
# Processing square  779
# non-defined chunk, skipped.
# Processing square  780
# non-defined chunk, skipped.
# Processing square  781
# non-defined chunk, skipped.
# Processing square  782
# non-defined chunk, skipped.
# Processing square  783
# non-defined chunk, skipped.
# Processing square  784
# non-defined chunk, skipped.
# Processing square  785
# non-defined chunk, skipped.
# Processing square  786
# non-defined chunk, skipped.
# Processing square  787
# non-defined chunk, skipped.
# Processing square  788
# non-defined chunk, skipped.
# Processing square  789
# non-defined chunk, skipped.
# Processing square  790
# non-defined chunk, skipped.
# Processing square  791
# non-defined chunk, skipped.
# Processing square  792
# non-defined chunk, skipped.
# Processing square  793
# non-defined chunk, skipped.
# Processing square  794
# non-defined chunk, skipped.
# Processing square  795
# non-defined chunk, skipped.
# Processing square  796
# non-defined chunk, skipped.
# Processing square  797
# non-defined chunk, skipped.
# Processing square  798
# non-defined chunk, skipped.
# Processing square  799
# non-defined chunk, skipped.
# Processing square  800
# non-defined chunk, skipped.
# Processing square  801
# non-defined chunk, skipped.
# Processing square  802
# non-defined chunk, skipped.
# Processing square  803
# non-defined chunk, skipped.
# Processing square  804
# non-defined chunk, skipped.
# Processing square  805
# non-defined chunk, skipped.
# Processing square  806
# non-defined chunk, skipped.
# Processing square  807
# non-defined chunk, skipped.
# Processing square  808
# non-defined chunk, skipped.
# Processing square  809
# non-defined chunk, skipped.
# Processing square  810
# non-defined chunk, skipped.
# Processing square  811
# non-defined chunk, skipped.
# Processing square  812
# non-defined chunk, skipped.
# Processing square  813
# non-defined chunk, skipped.
# Processing square  814
# non-defined chunk, skipped.
# Processing square  815
# non-defined chunk, skipped.
# Processing square  816
# non-defined chunk, skipped.
# Processing square  817
# non-defined chunk, skipped.
# Processing square  818
# non-defined chunk, skipped.
# Processing square  819
# non-defined chunk, skipped.
# Processing square  820
# non-defined chunk, skipped.
# Processing square  821
# non-defined chunk, skipped.
# Processing square  822
# non-defined chunk, skipped.
# Processing square  823
# non-defined chunk, skipped.
# Processing square  824
# non-defined chunk, skipped.
# Processing square  825
# non-defined chunk, skipped.
# Processing square  826
# non-defined chunk, skipped.
# Processing square  827
# non-defined chunk, skipped.
# Processing square  828
# non-defined chunk, skipped.
# Processing square  829
# non-defined chunk, skipped.
# Processing square  830
# non-defined chunk, skipped.
# Processing square  831
# non-defined chunk, skipped.
# Processing square  832
# non-defined chunk, skipped.
# Processing square  833
# non-defined chunk, skipped.
# Processing square  834
# non-defined chunk, skipped.
# Processing square  835
# non-defined chunk, skipped.
# Processing square  836
# non-defined chunk, skipped.
# Processing square  837
# non-defined chunk, skipped.
# Processing square  838
# non-defined chunk, skipped.
# Processing square  839
# non-defined chunk, skipped.
# Processing square  840
# non-defined chunk, skipped.
# Processing square  841
# non-defined chunk, skipped.
# Processing square  842
# non-defined chunk, skipped.
# Processing square  843
# non-defined chunk, skipped.
# Processing square  844
# non-defined chunk, skipped.
# Processing square  845
# non-defined chunk, skipped.
# Processing square  846
# non-defined chunk, skipped.
# Processing square  847
# non-defined chunk, skipped.
# Processing square  848
# non-defined chunk, skipped.
# Processing square  849
# non-defined chunk, skipped.
# Processing square  850
# non-defined chunk, skipped.
# Processing square  851
# non-defined chunk, skipped.
# Processing square  852
# non-defined chunk, skipped.
# Processing square  853
# non-defined chunk, skipped.
# Processing square  854
# non-defined chunk, skipped.
# Processing square  855
# non-defined chunk, skipped.
# Processing square  856
# non-defined chunk, skipped.
# Processing square  857
# non-defined chunk, skipped.
# Processing square  858
# non-defined chunk, skipped.
# Processing square  859
# non-defined chunk, skipped.
# Processing square  860
# non-defined chunk, skipped.
# Processing square  861
# non-defined chunk, skipped.
# Processing square  862
# non-defined chunk, skipped.
# Processing square  863
# non-defined chunk, skipped.
# Processing square  864
# non-defined chunk, skipped.
# Processing square  865
# non-defined chunk, skipped.
# Processing square  866
# non-defined chunk, skipped.
# Processing square  867
# non-defined chunk, skipped.
# Processing square  868
# non-defined chunk, skipped.
# Processing square  869
# non-defined chunk, skipped.
# Processing square  870
# non-defined chunk, skipped.
# Processing square  871
# non-defined chunk, skipped.
# Processing square  872
# non-defined chunk, skipped.
# Processing square  873
# non-defined chunk, skipped.
# Processing square  874
# non-defined chunk, skipped.
# Processing square  875
# non-defined chunk, skipped.
# Processing square  876
# non-defined chunk, skipped.
# Processing square  877
# non-defined chunk, skipped.
# Processing square  878
# non-defined chunk, skipped.
# Processing square  879
# non-defined chunk, skipped.
# Processing square  880
# non-defined chunk, skipped.
# Processing square  881
# non-defined chunk, skipped.
# Processing square  882
# non-defined chunk, skipped.
# Processing square  883
# non-defined chunk, skipped.
# Processing square  884
# non-defined chunk, skipped.
# Processing square  885
# non-defined chunk, skipped.
# Processing square  886
# non-defined chunk, skipped.
# Processing square  887
# non-defined chunk, skipped.
# Processing square  888
# non-defined chunk, skipped.
# Processing square  889
# non-defined chunk, skipped.
# Processing square  890
# non-defined chunk, skipped.
# Processing square  891
# non-defined chunk, skipped.
# Processing square  892
# non-defined chunk, skipped.
# Processing square  893
# non-defined chunk, skipped.
# Processing square  894
# non-defined chunk, skipped.
# Processing square  895
# non-defined chunk, skipped.
# Processing square  896
# non-defined chunk, skipped.
# Processing square  897
# non-defined chunk, skipped.
# Processing square  898
# non-defined chunk, skipped.
# Processing square  899
# non-defined chunk, skipped.
# Processing square  900
# non-defined chunk, skipped.
# Processing square  901
# non-defined chunk, skipped.
# Processing square  902
# non-defined chunk, skipped.
# Processing square  903
# non-defined chunk, skipped.
# Processing square  904
# non-defined chunk, skipped.
# Processing square  905
# non-defined chunk, skipped.
# Processing square  906
# non-defined chunk, skipped.
# Processing square  907
# non-defined chunk, skipped.
# Processing square  908
# non-defined chunk, skipped.
# Processing square  909
# non-defined chunk, skipped.
# Processing square  910
# non-defined chunk, skipped.
# Processing square  911
# non-defined chunk, skipped.
# Processing square  912
# non-defined chunk, skipped.
# Processing square  913
# non-defined chunk, skipped.
# Processing square  914
# non-defined chunk, skipped.
# Processing square  915
# non-defined chunk, skipped.
# Processing square  916
# non-defined chunk, skipped.
# Processing square  917
# non-defined chunk, skipped.
# Processing square  918
# non-defined chunk, skipped.
# Processing square  919
# non-defined chunk, skipped.
# Processing square  920
# non-defined chunk, skipped.
# Processing square  921
# non-defined chunk, skipped.
# Processing square  922
# non-defined chunk, skipped.
# Processing square  923
# non-defined chunk, skipped.
# Processing square  924
# non-defined chunk, skipped.
# Processing square  925
# non-defined chunk, skipped.
# Processing square  926
# non-defined chunk, skipped.
# Processing square  927
# non-defined chunk, skipped.
# Processing square  928
# non-defined chunk, skipped.
# Processing square  929
# non-defined chunk, skipped.
# Processing square  930
# non-defined chunk, skipped.
# Processing square  931
# non-defined chunk, skipped.
# Processing square  932
# non-defined chunk, skipped.
# Processing square  933
# non-defined chunk, skipped.
# Processing square  934
# non-defined chunk, skipped.
# Processing square  935
# non-defined chunk, skipped.
# Processing square  936
# non-defined chunk, skipped.
# Processing square  937
# non-defined chunk, skipped.
# Processing square  938
# non-defined chunk, skipped.
# Processing square  939
# non-defined chunk, skipped.
# Processing square  940
# non-defined chunk, skipped.
# Processing square  941
# non-defined chunk, skipped.
# ...
# Processing square  7549
# Processing square  7550
# Processing square  7551
# Processing square  7552
# Processing square  7553
# Processing square  7554
# Processing square  7555
# Processing square  7556
# Processing square  7557
# Processing square  7558
# Processing square  7559
# Processing square  7560
# Processing square  7561
# non-defined chunk, skipped.
# Processing square  7562
# non-defined chunk, skipped.
# Processing square  7563
# non-defined chunk, skipped.
# Processing square  7564
# non-defined chunk, skipped.
# Processing square  7565
# non-defined chunk, skipped.
# Processing square  7566
# non-defined chunk, skipped.
# Processing square  7567
# non-defined chunk, skipped.
# Processing square  7568
# non-defined chunk, skipped.
# Processing square  7569
# non-defined chunk, skipped.
# Processing square  7570
# non-defined chunk, skipped.
# Processing square  7571
# non-defined chunk, skipped.
# Processing square  7572
# non-defined chunk, skipped.
# Processing square  7573
# non-defined chunk, skipped.
# Processing square  7574
# non-defined chunk, skipped.
# Processing square  7575
# non-defined chunk, skipped.
# Processing square  7576
# non-defined chunk, skipped.
# Processing square  7577
# non-defined chunk, skipped.
# Processing square  7578
# non-defined chunk, skipped.
# Processing square  7579
# non-defined chunk, skipped.
# Processing square  7580
# non-defined chunk, skipped.
# Processing square  7581
# non-defined chunk, skipped.
# Processing square  7582
# non-defined chunk, skipped.
# Processing square  7583
# non-defined chunk, skipped.
# Processing square  7584
# non-defined chunk, skipped.
# Processing square  7585
# non-defined chunk, skipped.
# Processing square  7586
# non-defined chunk, skipped.
# Processing square  7587
# non-defined chunk, skipped.
# Processing square  7588
# non-defined chunk, skipped.
# Processing square  7589
# non-defined chunk, skipped.
# Processing square  7590
# non-defined chunk, skipped.
# Processing square  7591
# non-defined chunk, skipped.
# Processing square  7592
# Processing square  7593
# Processing square  7594
# Processing square  7595
# Processing square  7596
# Processing square  7597
# Processing square  7598
# Processing square  7599
# Processing square  7600
# Processing square  7601
# Processing square  7602
# Processing square  7603
# Processing square  7604
# Processing square  7605
# Processing square  7606
# Processing square  7607
# Processing square  7608
# Processing square  7609
# Processing square  7610
# Processing square  7611
# Processing square  7612
# Processing square  7613
# Processing square  7614
# Processing square  7615
# Processing square  7616
# Processing square  7617
# non-defined chunk, skipped.
# Processing square  7618
# non-defined chunk, skipped.
# Processing square  7619
# non-defined chunk, skipped.
# Processing square  7620
# non-defined chunk, skipped.
# Processing square  7621
# non-defined chunk, skipped.
# Processing square  7622
# non-defined chunk, skipped.
# Processing square  7623
# non-defined chunk, skipped.
# Processing square  7624
# non-defined chunk, skipped.
# Processing square  7625
# non-defined chunk, skipped.
# Processing square  7626
# non-defined chunk, skipped.
# Processing square  7627
# non-defined chunk, skipped.
# Processing square  7628
# non-defined chunk, skipped.
# Processing square  7629
# non-defined chunk, skipped.
# Processing square  7630
# non-defined chunk, skipped.
# Processing square  7631
# non-defined chunk, skipped.
# Processing square  7632
# non-defined chunk, skipped.
# Processing square  7633
# non-defined chunk, skipped.
# Processing square  7634
# non-defined chunk, skipped.
# Processing square  7635
# non-defined chunk, skipped.
# Processing square  7636
# non-defined chunk, skipped.
# Processing square  7637
# non-defined chunk, skipped.
# Processing square  7638
# non-defined chunk, skipped.
# Processing square  7639
# non-defined chunk, skipped.
# Processing square  7640
# non-defined chunk, skipped.
# Processing square  7641
# non-defined chunk, skipped.
# Processing square  7642
# non-defined chunk, skipped.
# Processing square  7643
# non-defined chunk, skipped.
# Processing square  7644
# non-defined chunk, skipped.
# Processing square  7645
# non-defined chunk, skipped.
# Processing square  7646
# non-defined chunk, skipped.
# Processing square  7647
# non-defined chunk, skipped.
# Processing square  7648
# Processing square  7649
# Processing square  7650
# Processing square  7651
# Processing square  7652
# Processing square  7653
# Processing square  7654
# Processing square  7655
# Processing square  7656
# Processing square  7657
# Processing square  7658
# Processing square  7659
# Processing square  7660
# Processing square  7661
# Processing square  7662
# Processing square  7663
# Processing square  7664
# Processing square  7665
# Processing square  7666
# Processing square  7667
# Processing square  7668
# Processing square  7669
# Processing square  7670
# Processing square  7671
# Processing square  7672
# Processing square  7673
# non-defined chunk, skipped.
# Processing square  7674
# non-defined chunk, skipped.
# Processing square  7675
# non-defined chunk, skipped.
# Processing square  7676
# non-defined chunk, skipped.
# Processing square  7677
# non-defined chunk, skipped.
# Processing square  7678
# non-defined chunk, skipped.
# Processing square  7679
# non-defined chunk, skipped.
# Processing square  7680
# non-defined chunk, skipped.
# Processing square  7681
# non-defined chunk, skipped.
# Processing square  7682
# non-defined chunk, skipped.
# Processing square  7683
# non-defined chunk, skipped.
# Processing square  7684
# non-defined chunk, skipped.
# Processing square  7685
# non-defined chunk, skipped.
# Processing square  7686
# non-defined chunk, skipped.
# Processing square  7687
# non-defined chunk, skipped.
# Processing square  7688
# non-defined chunk, skipped.
# Processing square  7689
# non-defined chunk, skipped.
# Processing square  7690
# non-defined chunk, skipped.
# Processing square  7691
# non-defined chunk, skipped.
# Processing square  7692
# non-defined chunk, skipped.
# Processing square  7693
# non-defined chunk, skipped.
# Processing square  7694
# non-defined chunk, skipped.
# Processing square  7695
# non-defined chunk, skipped.
# Processing square  7696
# non-defined chunk, skipped.
# Processing square  7697
# non-defined chunk, skipped.
# Processing square  7698
# non-defined chunk, skipped.
# Processing square  7699
# non-defined chunk, skipped.
# Processing square  7700
# non-defined chunk, skipped.
# Processing square  7701
# non-defined chunk, skipped.
# Processing square  7702
# non-defined chunk, skipped.
# Processing square  7703
# non-defined chunk, skipped.
# Processing square  7704
# Processing square  7705
# Processing square  7706
# Processing square  7707
# Processing square  7708
# Processing square  7709
# Processing square  7710
# Processing square  7711
# Processing square  7712
# Processing square  7713
# Processing square  7714
# Processing square  7715
# Processing square  7716
# Processing square  7717
# Processing square  7718
# Processing square  7719
# Processing square  7720
# Processing square  7721
# Processing square  7722
# Processing square  7723
# Processing square  7724
# Processing square  7725
# Processing square  7726
# Processing square  7727
# Processing square  7728
# Processing square  7729
# non-defined chunk, skipped.
# Processing square  7730
# non-defined chunk, skipped.
# Processing square  7731
# non-defined chunk, skipped.
# Processing square  7732
# non-defined chunk, skipped.
# Processing square  7733
# non-defined chunk, skipped.
# Processing square  7734
# non-defined chunk, skipped.
# Processing square  7735
# non-defined chunk, skipped.
# Processing square  7736
# non-defined chunk, skipped.
# Processing square  7737
# non-defined chunk, skipped.
# Processing square  7738
# non-defined chunk, skipped.
# Processing square  7739
# non-defined chunk, skipped.
# Processing square  7740
# non-defined chunk, skipped.
# Processing square  7741
# non-defined chunk, skipped.
# Processing square  7742
# non-defined chunk, skipped.
# Processing square  7743
# non-defined chunk, skipped.
# Processing square  7744
# non-defined chunk, skipped.
# Processing square  7745
# non-defined chunk, skipped.
# Processing square  7746
# non-defined chunk, skipped.
# Processing square  7747
# non-defined chunk, skipped.
# Processing square  7748
# non-defined chunk, skipped.
# Processing square  7749
# non-defined chunk, skipped.
# Processing square  7750
# non-defined chunk, skipped.
# Processing square  7751
# non-defined chunk, skipped.
# Processing square  7752
# non-defined chunk, skipped.
# Processing square  7753
# non-defined chunk, skipped.
# Processing square  7754
# non-defined chunk, skipped.
# Processing square  7755
# non-defined chunk, skipped.
# Processing square  7756
# non-defined chunk, skipped.
# Processing square  7757
# non-defined chunk, skipped.
# Processing square  7758
# non-defined chunk, skipped.
# Processing square  7759
# non-defined chunk, skipped.
# Processing square  7760
# Processing square  7761
# Processing square  7762
# Processing square  7763
# Processing square  7764
# Processing square  7765
# Processing square  7766
# Processing square  7767
# Processing square  7768
# Processing square  7769
# Processing square  7770
# Processing square  7771
# Processing square  7772
# Processing square  7773
# Processing square  7774
# Processing square  7775
# Processing square  7776
# Processing square  7777
# Processing square  7778
# Processing square  7779
# Processing square  7780
# Processing square  7781
# Processing square  7782
# Processing square  7783
# Processing square  7784
# Processing square  7785
# non-defined chunk, skipped.
# Processing square  7786
# non-defined chunk, skipped.
# Processing square  7787
# non-defined chunk, skipped.
# Processing square  7788
# non-defined chunk, skipped.
# Processing square  7789
# non-defined chunk, skipped.
# Processing square  7790
# non-defined chunk, skipped.
# Processing square  7791
# non-defined chunk, skipped.
# Processing square  7792
# non-defined chunk, skipped.
# Processing square  7793
# non-defined chunk, skipped.
# Processing square  7794
# non-defined chunk, skipped.
# Processing square  7795
# non-defined chunk, skipped.
# Processing square  7796
# non-defined chunk, skipped.
# Processing square  7797
# non-defined chunk, skipped.
# Processing square  7798
# non-defined chunk, skipped.
# Processing square  7799
# non-defined chunk, skipped.
# Processing square  7800
# non-defined chunk, skipped.
# Processing square  7801
# non-defined chunk, skipped.
# Processing square  7802
# non-defined chunk, skipped.
# Processing square  7803
# non-defined chunk, skipped.
# Processing square  7804
# non-defined chunk, skipped.
# Processing square  7805
# non-defined chunk, skipped.
# Processing square  7806
# non-defined chunk, skipped.
# Processing square  7807
# non-defined chunk, skipped.
# Processing square  7808
# non-defined chunk, skipped.
# Processing square  7809
# non-defined chunk, skipped.
# Processing square  7810
# non-defined chunk, skipped.
# Processing square  7811
# non-defined chunk, skipped.
# Processing square  7812
# non-defined chunk, skipped.
# Processing square  7813
# non-defined chunk, skipped.
# Processing square  7814
# non-defined chunk, skipped.
# Processing square  7815
# non-defined chunk, skipped.
# Processing square  7816
# Processing square  7817
# Processing square  7818
# Processing square  7819
# Processing square  7820
# Processing square  7821
# Processing square  7822
# Processing square  7823
# Processing square  7824
# Processing square  7825
# Processing square  7826
# Processing square  7827
# Processing square  7828
# Processing square  7829
# Processing square  7830
# Processing square  7831
# Processing square  7832
# Processing square  7833
# Processing square  7834
# Processing square  7835
# Processing square  7836
# Processing square  7837
# Processing square  7838
# Processing square  7839
# Processing square  7840
# Processing square  7841
# non-defined chunk, skipped.
# Processing square  7842
# non-defined chunk, skipped.
# Processing square  7843
# non-defined chunk, skipped.
# Processing square  7844
# non-defined chunk, skipped.
# Processing square  7845
# non-defined chunk, skipped.
# Processing square  7846
# non-defined chunk, skipped.
# Processing square  7847
# non-defined chunk, skipped.
# Processing square  7848
# non-defined chunk, skipped.
# Processing square  7849
# non-defined chunk, skipped.
# Processing square  7850
# non-defined chunk, skipped.
# Processing square  7851
# non-defined chunk, skipped.
# Processing square  7852
# non-defined chunk, skipped.
# Processing square  7853
# non-defined chunk, skipped.
# Processing square  7854
# non-defined chunk, skipped.
# Processing square  7855
# non-defined chunk, skipped.
# Processing square  7856
# non-defined chunk, skipped.
# Processing square  7857
# non-defined chunk, skipped.
# Processing square  7858
# non-defined chunk, skipped.
# Processing square  7859
# non-defined chunk, skipped.
# Processing square  7860
# non-defined chunk, skipped.
# Processing square  7861
# non-defined chunk, skipped.
# Processing square  7862
# non-defined chunk, skipped.
# Processing square  7863
# non-defined chunk, skipped.
# Processing square  7864
# non-defined chunk, skipped.
# Processing square  7865
# non-defined chunk, skipped.
# Processing square  7866
# non-defined chunk, skipped.
# Processing square  7867
# non-defined chunk, skipped.
# Processing square  7868
# non-defined chunk, skipped.
# Processing square  7869
# non-defined chunk, skipped.
# Processing square  7870
# non-defined chunk, skipped.
# Processing square  7871
# non-defined chunk, skipped.
# Processing square  7872
# Processing square  7873
# Processing square  7874
# Processing square  7875
# Processing square  7876
# Processing square  7877
# Processing square  7878
# Processing square  7879
# Processing square  7880
# Processing square  7881
# Processing square  7882
# Processing square  7883
# Processing square  7884
# Processing square  7885
# Processing square  7886
# Processing square  7887
# Processing square  7888
# Processing square  7889
# Processing square  7890
# Processing square  7891
# Processing square  7892
# Processing square  7893
# Processing square  7894
# Processing square  7895
# Processing square  7896
# Processing square  7897
# non-defined chunk, skipped.
# Processing square  7898
# non-defined chunk, skipped.
# Processing square  7899
# non-defined chunk, skipped.
# Processing square  7900
# non-defined chunk, skipped.
# Processing square  7901
# non-defined chunk, skipped.
# Processing square  7902
# non-defined chunk, skipped.
# Processing square  7903
# non-defined chunk, skipped.
# Processing square  7904
# non-defined chunk, skipped.
# Processing square  7905
# non-defined chunk, skipped.
# Processing square  7906
# non-defined chunk, skipped.
# Processing square  7907
# non-defined chunk, skipped.
# Processing square  7908
# non-defined chunk, skipped.
# Processing square  7909
# non-defined chunk, skipped.
# Processing square  7910
# non-defined chunk, skipped.
# Processing square  7911
# non-defined chunk, skipped.
# Processing square  7912
# non-defined chunk, skipped.
# Processing square  7913
# non-defined chunk, skipped.
# Processing square  7914
# non-defined chunk, skipped.
# Processing square  7915
# non-defined chunk, skipped.
# Processing square  7916
# non-defined chunk, skipped.
# Processing square  7917
# non-defined chunk, skipped.
# Processing square  7918
# non-defined chunk, skipped.
# Processing square  7919
# non-defined chunk, skipped.
# Processing square  7920
# non-defined chunk, skipped.
# Processing square  7921
# non-defined chunk, skipped.
# Processing square  7922
# non-defined chunk, skipped.
# Processing square  7923
# non-defined chunk, skipped.
# Processing square  7924
# non-defined chunk, skipped.
# Processing square  7925
# non-defined chunk, skipped.
# Processing square  7926
# non-defined chunk, skipped.
# Processing square  7927
# non-defined chunk, skipped.
# Processing square  7928
# Processing square  7929
# Processing square  7930
# Processing square  7931
# Processing square  7932
# Processing square  7933
# Processing square  7934
# Processing square  7935
# Processing square  7936
# Processing square  7937
# Processing square  7938
# Processing square  7939
# Processing square  7940
# Processing square  7941
# Processing square  7942
# Processing square  7943
# Processing square  7944
# Processing square  7945
# Processing square  7946
# non-defined chunk, skipped.
# Processing square  7947
# non-defined chunk, skipped.
# Processing square  7948
# non-defined chunk, skipped.
# Processing square  7949
# non-defined chunk, skipped.
# Processing square  7950
# non-defined chunk, skipped.
# Processing square  7951
# non-defined chunk, skipped.
# Processing square  7952
# non-defined chunk, skipped.
# Sorting complete.
